# %%
import pandas as pd

# %%
data_path = '/home/hzchen/jyh/verl/data/rlpr_train.parquet'

# %%
df = pd.read_parquet(data_path, engine='pyarrow')
print(df.columns)
data_source_set = set()
for i in df['ability']:
    data_source_set.add(i)
print(len(df))
print(data_source_set)
# Out:
# Index(['data_source', 'prompt', 'ability', 'reward_model', 'extra_info'], dtype='object')
# 77687
# {'Engineering', 'Health', 'Economics', 'Business', 'Computer Science', 'Law', 'Finance', 'Chemistry', 'Other', 'Biology', 'Psychology', 'Philosophy', 'Other STEM', 'Physics'}
